-- %%
CREATE OR REPLACE TABLE analytics.digital_twin.dados_refrigeracao_gold AS
SELECT *
FROM read_files(
  '/Volumes/analytics/digital_twin/data/gold/dados_refrigeracao_gold.parquet',
  format => 'parquet'
);
